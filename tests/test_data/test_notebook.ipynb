# %%
import numpy as np
import roomacoustics.edc_noise_handling as nh
import roomacoustics as ra
from roomacoustics import analytic
from matplotlib import pyplot as plt 
# %load_ext autoreload
# %autoreload 2
from importlib.machinery import SourceFileLoader

test_enh = SourceFileLoader("test_edc_noise_handling", "/Users/johannes/ITA/roomacoustics/tests/test_edc_noise_handling.py").load_module()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of test_edc_noise_handling failed: Traceback (most recent call last):
#   File "/Users/johannes/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/johannes/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 376, in superreload
#     module = reload(module)
#   File "/Users/johannes/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/johannes/anaconda3/lib/python3.7/importlib/__init__.py", line 168, in reload
#     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# ModuleNotFoundError: spec not found for the module 'test_edc_noise_handling'
# ]

# %%
nh.intersection_time_lundeby(rir_array, sampling_rate, plot=True)
# Out:
# (array([       inf, 1.07212152]),
#  array([8.62590135, 2.00215833]),
#  array([        -inf, -39.96058542]))

# %%
print(rir_array)
# Out:
# [[-0.04132181 -0.12407317  0.4393961  ...  0.          0.
#    0.        ]
#  [-0.05991019 -0.10177295  0.39453403 ...  0.00231178 -0.01027753
#   -0.00532047]]

# %%
test_enh.test_noise_energy_2D()

# %%
test_enh.test_noise_energy_1D()
test_enh.test_noise_energy_2D()
test_enh.test_preprocessing_1D()
test_enh.test_preprocessing_2D()
test_enh.test_preprocessing_time_shift_1D()
test_enh.test_preprocessing_time_shift_2D()
test_enh.test_preprocessing_time_shift_channel_independent_1D()
test_enh.test_preprocessing_time_shift_channel_independent_2D()
test_enh.test_smoothed_rir_1D()
test_enh.test_smoothed_rir_2D()
test_enh.test_substracted_1D()
test_enh.test_substracted_2D()    
test_enh.test_edc_truncation_1D()
test_enh.test_edc_truncation_2D()
test_enh.test_edc_lundeby_1D()
test_enh.test_edc_lundeby_2D()
test_enh.test_edc_lundeby_chu_1D()
test_enh.test_edc_lundeby_chu_2D()
test_enh.test_edc_chu_1D()
test_enh.test_edc_chu_2D()
test_enh.test_intersection_time_1D()
test_enh.test_intersection_time_2D()    
test_enh.test_noise_energy_from_edc_1D()
test_enh.test_noise_energy_from_edc_2D()
